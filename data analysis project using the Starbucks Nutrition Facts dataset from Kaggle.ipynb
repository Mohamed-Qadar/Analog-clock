# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Qadar/Analog-clock/blob/main/data%20analysis%20project%20using%20the%20Starbucks%20Nutrition%20Facts%20dataset%20from%20Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# CSV dosyasını okuma
df = pd.read_csv('/content/starbucks.csv')

# %%
# İlk 5 satırı görüntüleme
#print(data.head())
df.head()
# Out:
#    Unnamed: 0                         item  calories   fat  carb  fiber  \
# 0           1                 8-Grain Roll       350   8.0    67      5
# 1           2            Apple Bran Muffin       350   9.0    64      7
# 2           3                Apple Fritter       420  20.0    59      0
# 3           4              Banana Nut Loaf       490  19.0    75      4
# 4           5  Birthday Cake Mini Doughnut       130   6.0    17      0
#
#    protein    type
# 0       10  bakery
# 1        6  bakery
# 2        5  bakery
# 3        7  bakery
# 4        0  bakery

# %%
print(df.columns)
# Out:
# Index(['item', 'calories', 'fat', 'carb', 'fiber', 'protein', 'type'], dtype='object')

# %%
print(df.head())
# Out:
#    Unnamed: 0                         item  calories   fat  carb  fiber  \
# 0           1                 8-Grain Roll       350   8.0    67      5
# 1           2            Apple Bran Muffin       350   9.0    64      7
# 2           3                Apple Fritter       420  20.0    59      0
# 3           4              Banana Nut Loaf       490  19.0    75      4
# 4           5  Birthday Cake Mini Doughnut       130   6.0    17      0
#
#    protein    type
# 0       10  bakery
# 1        6  bakery
# 2        5  bakery
# 3        7  bakery
# 4        0  bakery

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# item          0
# calories      0
# fat           0
# carb          0
# fiber         0
# protein       0
# type          0
# dtype: int64

# %%
# CSV dosyasını okuma ve ilk sütunu indeks olarak ayarlama
df = pd.read_csv('/content/starbucks.csv', index_col=0)

# %%
df.describe()
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df.groupby('type')['item'].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
df.groupby('type')['item'].count().plot()
plt.title("urun turleri")
plt.text(0,50,"urun kategori yelpazesi",bbox=dict(facecolor="yellow",alpha =0.5))
# Out:
# Text(0, 50, 'urun kategori yelpazesi')

# %%
sns.countplot(x="type",data =df,palette="deep")
plt.title("urunun sayilari")
plt.show()
# Out:
# <ipython-input-28-ca875a25b1dd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="type",data =df,palette="deep")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV dosyasını okuma
df = pd.read_csv('/content/starbucks.csv')

# Protein değerlerini kategorize etme
bins = [0, 5, 10, 15, 20, 25, 30]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30']  # Kategoriler
df['protein_category'] = pd.cut(df['protein'], bins=bins, labels=labels, right=False)

# Sayım grafiği oluşturma
sns.countplot(x="protein_category", data=df, palette="deep")

# Başlık ve etiketler ekleme
plt.title("Protein Kategorilerine Göre Ürün Sayıları")
plt.xlabel("Protein Kategorileri (g)")
plt.ylabel("Ürün Sayısı")

# Grafiği gösterme
plt.show()
# Out:
# <ipython-input-31-c0522d62755a>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="protein_category", data=df, palette="deep")

# %%
sns.catplot(kind="bar",x= "type", y="carb",data=df,hue="type", palette="deep")
plt.title("Protein Kategorilerine Göre Ürün Sayıları")
plt.show()

# %%
sns.catplot(kind="bar",x= "type", y="fiber",data=df,hue="type", palette="deep")
plt.title("fiber Kategorilerine Göre Ürün Sayıları")
plt.show()

# %%
print(df.dtypes)
# Out:
# Unnamed: 0             int64
# item                  object
# calories               int64
# fat                  float64
# carb                   int64
# fiber                  int64
# protein                int64
# type                  object
# protein_category    category
# dtype: object

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
 #Yalnızca sayısal sütunları seçme
#numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Sayısal sütunlar arasındaki korelasyonu hesaplama
correlation_matrix = numeric_df.corr()

# Korelasyon matrisini yazdırma
print("Korelasyon Matrisi:")
print(correlation_matrix)
# Out:
# Korelasyon Matrisi:
#             Unnamed: 0  calories       fat      carb     fiber   protein
# Unnamed: 0    1.000000 -0.219922 -0.174856 -0.405229  0.050665  0.448922
# calories     -0.219922  1.000000  0.758682  0.674999  0.260645  0.410398
# fat          -0.174856  0.758682  1.000000  0.144547 -0.028549  0.223470
# carb         -0.405229  0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber         0.050665  0.260645 -0.028549  0.213044  1.000000  0.488564
# protein       0.448922  0.410398  0.223470 -0.050789  0.488564  1.000000

# %%
#sns.heatmap(df.corr(),annot=True)
#ayni is gorur
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.title("kaaloriye yag")
sns.scatterplot(x="calories",y="fat",data=df,s=30,edgecolor="green")
plt.plot()
# Out:
# []

# %%
sns.displot(x="calories",data=df,color="green", kde=True)
plt.title("kalori grafiği")
plt.show()

# %%
sns.displot(x="protein",data=df,color="blue", kde=True)
plt.title("protein grafiği")
plt.show()

# %%
sns.displot(x="fat",data=df,color="red", kde=True)
plt.title("yag grafiği")
plt.show()

# %%
sns.displot(x="carb",data=df,color="yellow", kde=True)
plt.title("karbonhederat grafiği")
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0                         item  calories   fat  carb  fiber  \
# 0           1                 8-Grain Roll       350   8.0    67      5
# 1           2            Apple Bran Muffin       350   9.0    64      7
# 2           3                Apple Fritter       420  20.0    59      0
# 3           4              Banana Nut Loaf       490  19.0    75      4
# 4           5  Birthday Cake Mini Doughnut       130   6.0    17      0
#
#    protein    type protein_category
# 0       10  bakery            11-15
# 1        6  bakery             6-10
# 2        5  bakery             6-10
# 3        7  bakery             6-10
# 4        0  bakery              0-5

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
 x=df[["calories","fat", "carb","fiber","protein"]]
 y=df["type"]

# %%
x
# Out:
#     calories   fat  carb  fiber  protein
# 0        350   8.0    67      5       10
# 1        350   9.0    64      7        6
# 2        420  20.0    59      0        5
# 3        490  19.0    75      4        7
# 4        130   6.0    17      0        0
# ..       ...   ...   ...    ...      ...
# 72       420  13.0    46      6       32
# 73       390  13.0    36      2       34
# 74       300  12.0    44      0        8
# 75       300   4.0    57      3       10
# 76       300   3.5    60      3        7
#
# [77 rows x 5 columns]

# %%
y
# Out:
# 0       bakery
# 1       bakery
# 2       bakery
# 3       bakery
# 4       bakery
#         ...
# 72    sandwich
# 73    sandwich
# 74     parfait
# 75     parfait
# 76     parfait
# Name: type, Length: 77, dtype: object

# %%
 x_train,xtest,ytrain, ytest=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model=DecisionTreeClassifier()
model.fit(x_train,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(xtest)

# %%
accuracy=accuracy_score(ytest,y_pred)

# %%
print("doğruluk", accuracy)
# Out:
# doğruluk 0.75

# %%
prediction=model.predict([[550,22,4,70,9]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# ['bakery']

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(15,10))
plot_tree (model, feature_names=x.columns,class_names=model.classes_,filled=True)
plt.show()
